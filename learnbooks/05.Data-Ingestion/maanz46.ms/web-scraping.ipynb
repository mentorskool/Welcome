# %%
#@title 
# %%html
<marquee style='width: 100%; color: #00a7f4;font-size:30px;'><b>Welcome to Web Scraping Session</b></marquee>
# Out:
# <marquee style='width: 100%; color: #00a7f4;font-size:30px;'><b>Welcome to Web Scraping Session</b></marquee>

# %% [markdown]
# ## Import Libraries

# %%
import requests #import requests
from bs4 import BeautifulSoup #import beautifulsoup

# %% [markdown]
# ##Pass HTTP request to server

# %%
url = 'https://en.wikipedia.org/wiki/States_and_union_territories_of_India' #url from which we will extract data
response = requests.get(url)
#check request status
response.status_code
# Out:
# 200
